# %%
# Import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats
import statsmodels.api as sm
import warnings
from itertools import product
from datetime import datetime
import pyspark.sql.functions as F
warnings.filterwarnings('ignore')
plt.style.use('seaborn-poster')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-80623079d00b> in <module>
#      10 from itertools import product
#      11 from datetime import datetime
# ---> 12 import pyspark.sql.functions as F
#      13 warnings.filterwarnings('ignore')
#      14 plt.style.use('seaborn-poster')
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
philippine_df = pd.read_csv("https://raw.githubusercontent.com/zalven/covid-19-prediction-2021/main/covid_prediction_data/philippines_covid_cases.csv")

# %%
philippine_df.tail()
# Out:
#     iso_code continent     location        date  total_cases  new_cases  \
# 494      PHL      Asia  Philippines  2021-06-07    1276004.0     6526.0
# 495      PHL      Asia  Philippines  2021-06-08    1280773.0     4769.0
# 496      PHL      Asia  Philippines  2021-06-09    1286217.0     5444.0
# 497      PHL      Asia  Philippines  2021-06-10    1293687.0     7470.0
# 498      PHL      Asia  Philippines  2021-06-11    1300349.0     6662.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 494            6529.000       21969.0        71.0              143.286  ...
# 495            6472.286       22064.0        95.0              150.286  ...
# 496            6500.143       22190.0       126.0              147.429  ...
# 497            6541.143       22312.0       122.0              136.429  ...
# 498            6430.286       22507.0       195.0              138.571  ...
#
#      extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
# Resampling to monthly frequency
df_month = philippine_df.resample('M').mean()

# Resampling to annual frequency
df_year = philippine_df.resample('A-DEC').mean()

# Resampling to quarterly frequency
df_Q = philippine_df.resample('Q-DEC').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-b96a6db7badd> in <module>
#       1 # Resampling to monthly frequency
# ----> 2 df_month = philippine_df.resample('M').mean()
#       3
#       4 # Resampling to annual frequency
#       5 df_year = philippine_df.resample('A-DEC').mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8367
#    8368         axis = self._get_axis_number(axis)
# -> 8369         return get_resampler(
#    8370             self,
#    8371             freq=rule,
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in get_resampler(obj, kind, **kwds)
#    1309     """
#    1310     tg = TimeGrouper(**kwds)
# -> 1311     return tg._get_resampler(obj, kind=kind)
#    1312
#    1313
#
# ...
