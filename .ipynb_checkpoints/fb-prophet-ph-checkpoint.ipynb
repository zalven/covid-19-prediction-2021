# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import fbprophet 
from fbprophet import Prophet
from fbprophet.diagnostics import cross_validation
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/zalven/covid-19-prediction-2021/main/covid_prediction_data/philippines_covid_cases.csv')
df = df[['date','new_cases']]

# %%
df.tail()
# Out:
#            date  new_cases
# 494  2021-06-07     6526.0
# 495  2021-06-08     4769.0
# 496  2021-06-09     5444.0
# 497  2021-06-10     7470.0
# 498  2021-06-11     6662.0

# %%
df['new_cases'].plot()
# Out:
# <AxesSubplot:>

# %%
df.columns = ['ds','y']
df.tail()
# Out:
#              ds       y
# 494  2021-06-07  6526.0
# 495  2021-06-08  4769.0
# 496  2021-06-09  5444.0
# 497  2021-06-10  7470.0
# 498  2021-06-11  6662.0

# %%
df['ds'] = pd.to_datetime(df['ds'])

# %%
model = Prophet()

# %%
df.columns
# Out:
# Index(['ds', 'y'], dtype='object')

# %%
model.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_dates = model.make_future_dataframe(periods=100)
future_dates.tail()
# Out:
#             ds
# 594 2021-09-15
# 595 2021-09-16
# 596 2021-09-17
# 597 2021-09-18
# 598 2021-09-19

# %%
prediction = model.predict( future_dates)
prediction.tail()
# Out:
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 594 2021-09-15  12628.308828  10213.042414  14296.179220  12059.951097
# 595 2021-09-16  12671.037285  10583.909660  14704.005320  12095.436686
# 596 2021-09-17  12713.765742  10969.470037  15014.920047  12127.872031
# 597 2021-09-18  12756.494199  11105.504347  15221.579396  12161.587958
# 598 2021-09-19  12799.222655  10913.326586  14929.947071  12195.631122
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 594  13169.980995     -395.144579           -395.144579           -395.144579
# 595  13220.952371      -44.536255            -44.536255            -44.536255
# 596  13267.898688      356.866547            356.866547            356.866547
# 597  13323.141450      336.892643            336.892643            336.892643
# 598  13379.119358       95.930347             95.930347             95.930347
#
#          weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 594 -395.144579   -395.144579   -395.144579                   0.0
# 595  -44.536255    -44.536255    -44.536255                   0.0
# 596  356.866547    356.866547    356.866547                   0.0
# 597  336.892643    336.892643    336.892643                   0.0
# 598   95.930347     95.930347     95.930347                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 594                         0.0                         0.0  12233.164249
# 595                         0.0                         0.0  12626.501030
# 596                         0.0                         0.0  13070.632289
# 597                         0.0                         0.0  13093.386841
# 598                         0.0                         0.0  12895.153002

# %%
model.plot( prediction )

# %%
model.plot_components( prediction )

# %%
df_cv = cross_validation(model, initial='730 days', period='180 days', horizon = '365 days')
df_cv.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-322ccaa74fbf> in <module>
# ----> 1 df_cv = cross_validation(model, initial='730 days', period='180 days', horizon = '365 days')
#       2 df_cv.head()
#
# ~\anaconda3\lib\site-packages\fbprophet\diagnostics.py in cross_validation(model, horizon, period, initial, parallel, cutoffs)
#     138             initial = pd.Timedelta(initial)
#     139         # Compute Cutoffs
# --> 140         cutoffs = generate_cutoffs(df, horizon, initial, period)
#     141     else:
#     142         initial = cutoffs[0] - df['ds'].min()
#
# ~\anaconda3\lib\site-packages\fbprophet\diagnostics.py in generate_cutoffs(df, horizon, initial, period)
#      49     result = result[:-1]
#      50     if len(result) == 0:
# ---> 51         raise ValueError(
#      52             'Less data than horizon after initial window. '
#      53             'Make horizon or initial shorter.'
#
# ValueError: Less data than horizon after initial window. Make horizon or initial shorter.
